# %%
from My_Module import My_gui_test, My_clustering, My_post, My_pre_clustering
import matplotlib as mpl
from matplotlib.patches import Circle
import matplotlib.pyplot as plt
from matplotlib.collections import PatchCollection
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
import pickle

# %%
My_gui_test.execute_clustering_gui()
# Out:
# Resolution: 0.1
# Clusters: 132
# 0.21930980682373047
# 5.620169401168823
# False
# [(0, 0, 1, 0.4), (0, 0, 1, 0.4), (0, 0, 1, 0.4), (0, 0, 1, 0.4), (0, 0, 1, 0.4), (0, 0, 1, 0.4), (0, 0, 1, 0.4), (0, 0, 1, 0.4), (0, 0, 1, 0.4), (0, 0, 1, 0.4), (0, 0, 1, 0.4), (0, 0, 1, 0.4), (0, 0, 1, 0.4), (0, 0, 1, 0.4), (0, 0, 1, 0.4), (0, 0, 1, 0.4), (0, 0, 1, 0.4), (0, 0, 1, 0.4), (0, 0, 1, 0.4), (0, 0, 1, 0.4)]

# %%
test = pickle.load(open('test.p','rb'))

# %%
test.keys()
# Out:
# dict_keys(['translation', 'translation_reverse', 'global_frequency', 'Gr', 'chart', 'cluster_info', 'ClId', 'labels', 'nodes'])

# %%
k2 = pickle.load(open('k2','rb'))

# %%
k2.keys()
# Out:
# dict_keys(['graph', 'translation'])
